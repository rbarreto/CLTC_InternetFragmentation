# %%
import pandas as pd
import numpy as np
import csv

# %%
csvData = [["AF","Afghanistan",0.04,0,0,0.04],["AL","Albania",0,0,-0.01,0],["DZ","Algeria",0,-10,-0.01,0],["AS","American Samoa",0,-10,-0.04,0],["AD","Andorra",0,0,0.01,0],["AO","Angola",0,0,-0.05,0],["AI","Anguilla",0,0,-0.05,0],["AQ","Antarctica",0,0,0,0],["AG","Antigua & Barbuda",0,10,-0.06,0],["AR","Argentina",7.86,0,0,7.86],["AM","Armenia",1.63,0,0,1.63],["AW","Aruba",0,0,0.01,0],["AU","Australia",16.85,0,0,16.85],["AT","Austria",10.54,0,-0.01,10.54],["AZ","Azerbaijan",0,0,0,0],["BS","Bahamas",0,0,0,0],["BH","Bahrain",0,0,0.02,0],["BD","Bangladesh",0.04,0,0,0.04],["BB","Barbados",0,0,0,0],["BY","Belarus",0.04,0,0,0.04],["BE","Belgium",52.83,0,-0.01,52.83],["BZ","Belize",3.34,0,-0.01,3.34],["BJ","Benin",0.01,0,0.02,0.01],["BM","Bermuda",0,0,0.03,0],["BT","Bhutan",4.54,-10,-0.01,4.54],["BO","Bolivia",13.48,-50,-0.01,13.48],["BA","Bosnia & Herzegovina",4.75,-70,0,4.75],["BW","Botswana",0,0,-0.01,0],["BV","Bouvet Island",0,0,0,0],["BR","Brazil",27.66,-50,0.05,27.66],["IO","British Indian Ocean Territory",0,0,0,0],["VG","British Virgin Islands",0.88,0,-0.04,0.88],["BN","Brunei",0,0,-0.02,0],["BG","Bulgaria",1.48,0,0,1.48],["BF","Burkina Faso",0,-10,-0.02,0],["BI","Burundi",0,0,0.08,0],["KH","Cambodia",0.04,0,-0.01,0.04],["CM","Cameroon",0.07,0,-0.03,0.07],["CA","Canada",23.28,0,0.01,23.28],["CV","Cape Verde",0,0,-0.07,0],["BQ","Caribbean Netherlands",0,0,0.03,0],["KY","Cayman Islands",0,0,0,0],["CF","Central African Republic",0,0,-0.01,0],["TD","Chad",0,0,-0.04,0],["CL","Chile",0.13,0,0,0.13],["CN","China",5.05,0,-0.67,5.05],["CX","Christmas Island",0,0,0,0],["CC","Cocos (Keeling) Islands",0,0,0,0],["CO","Colombia",1.12,0,0,1.12],["KM","Comoros",0,-20,0.02,0],["CG","Congo - Brazzaville",0.62,0,0.05,0.62],["CD","Congo - Kinshasa",0.02,0,-0.08,0.02],["CK","Cook Islands",0,0,0,0],["CR","Costa Rica",0.1,0,-0.01,0.1],["HR","Croatia",0.04,0,0,0.04],["CU","Cuba",0,0,0.03,0],["AN","Curaçao",0,0,0,0],["CW","Curaçao",0.05,0,0.01,0.05],["CY","Cyprus",0.09,0,0.01,0.09],["CZ","Czechia",12.05,-10,0,12.05],["CI","Côte d’Ivoire",0.05,-10,-0.01,0.05],["DK","Denmark",3.51,0,0,3.51],["DJ","Djibouti",0,-10,0.11,2000.11],["DM","Dominica",0,0,0.01,0],["DO","Dominican Republic",1.21,-10,-0.03,1.21],["EC","Ecuador",19.07,-10,-0.02,19.07],["EG","Egypt",1.62,0,0,1.62],["SV","El Salvador",0.01,0,-0.01,0.01],["GQ","Equatorial Guinea",0,0,-0.19,0],["ER","Eritrea",0,0,0,0],["EE","Estonia",26.19,-10,0.01,26.19],["SZ","Eswatini",0,-20,0
albard & Jan Mayen",0,0,0,0],["SE","Sweden",5.66,0,0,5.66],["CH","Switzerland",29.28,0,0.03,29.28],["SY","Syria",0,0,-0.01,0],["ST","São Tomé & Príncipe",0,0,0,0],["TW","Taiwan",32.03,0,0,32.03],["TJ","Tajikistan",0.04,-10,0.02,0.04],["TZ","Tanzania",0.11,0,0,0.11],["TH","Thailand",22.93,-10,-0.01,22.93],["TL","Timor-Leste",0.07,0,0.07,0.07],["TG","Togo",3.59,0,-0.01,3.59],["TK","Tokelau",0,0,0,0],["TO","Tonga",0.26,0,-0.07,0.26],["TT","Trinidad & Tobago",20.6,-10,-0.03,20.6],["TN","Tunisia",0.01,0,0,0.01],["TR","Turkey",0.01,0,0,0.01],["TM","Turkmenistan",0.7,0,-0.04,0.7],["TC","Turks & Caicos Islands",0,0,0.07,0],["TV","Tuvalu",0,0,0,0],["UM","U.S. Outlying Islands",0,0,0,0],["VI","U.S. Virgin Islands",0.1,0,-0.02,0.1],["UG","Uganda",0.27,0,0.01,0.27],["UA","Ukraine",2.02,0,0.01,2.02],["AE","United Arab Emirates",13.77,0,0.42,1000.42],["GB","United Kingdom",23.24,0,-0.02,23.24],["US","United States",38.02,0,0.01,38.02],["ZZ","Unknown Region",1.61,0,0.01,1.61],["UY","Uruguay",36.89,-630,-0.05,36.89],["UZ","Uzbekistan",0.1,0,0,0.1],["VU","Vanuatu",0,10,0.12,2000.12],["VA","Vatican City",0,0,0,0],["VE","Venezuela",0,0,-0.01,0],["VN","Vietnam",38.74,0,0.01,38.74],["WF","Wallis & Futuna",0,0,0,0],["EH","Western Sahara",0,0,0,0],["XC","XC",0,0,0,0],["YE","Yemen",0.02,-10,0.04,0.02],["YD","Yemen",0,0,0,0],["ZM","Zambia",0.7,-30,-0.02,0.7],["ZW","Zimbabwe",5.91,0,-0.01,5.91],["AX","Åland Islands",25.54,-10,0.07,25.54]]

with open('ipv6.csv', 'w', newline='', encoding='utf-8') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(csvData)
    
csvFile.close()

# %%
with open('ipv6.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        print(row)
# Out:
# ['AF', 'Afghanistan', '0.04', '0', '0', '0.04']
# ['AL', 'Albania', '0', '0', '-0.01', '0']
# ['DZ', 'Algeria', '0', '-10', '-0.01', '0']
# ['AS', 'American Samoa', '0', '-10', '-0.04', '0']
# ['AD', 'Andorra', '0', '0', '0.01', '0']
# ['AO', 'Angola', '0', '0', '-0.05', '0']
# ['AI', 'Anguilla', '0', '0', '-0.05', '0']
# ['AQ', 'Antarctica', '0', '0', '0', '0']
# ['AG', 'Antigua & Barbuda', '0', '10', '-0.06', '0']
# ['AR', 'Argentina', '7.86', '0', '0', '7.86']
# ['AM', 'Armenia', '1.63', '0', '0', '1.63']
# ['AW', 'Aruba', '0', '0', '0.01', '0']
# ['AU', 'Australia', '16.85', '0', '0', '16.85']
# ['AT', 'Austria', '10.54', '0', '-0.01', '10.54']
# ['AZ', 'Azerbaijan', '0', '0', '0', '0']
# ['BS', 'Bahamas', '0', '0', '0', '0']
# ['BH', 'Bahrain', '0', '0', '0.02', '0']
# ['BD', 'Bangladesh', '0.04', '0', '0', '0.04']
# ['BB', 'Barbados', '0', '0', '0', '0']
# ['BY', 'Belarus', '0.04', '0', '0', '0.04']
# ['BE', 'Belgium', '52.83', '0', '-0.01', '52.83']
# ...

# %%
df = pd.read_csv('ipv6.csv')

# %%
df.to_csv('ipv6.csv', index=False, header = False)

# %%
df_csv = pd.read_csv('ipv6.csv', names = ['Country Abbreviation', 'Country Name', 'IPv6 Adoption Percentage', 'Latency', 'Impact','Repeat'], header=1)

# %%
df_csv
# Out:
#     Country Abbreviation                    Country Name  \
# 0                     AS                  American Samoa
# 1                     AD                         Andorra
# 2                     AO                          Angola
# 3                     AI                        Anguilla
# 4                     AQ                      Antarctica
# 5                     AG               Antigua & Barbuda
# 6                     AR                       Argentina
# 7                     AM                         Armenia
# 8                     AW                           Aruba
# 9                     AU                       Australia
# 10                    AT                         Austria
# 11                    AZ                      Azerbaijan
# 12                    BS                         Bahamas
# 13                    BH                         Bahrain
# 14                    BD                      Bangladesh
# ...

# %%
df_csv = df_csv.drop('Country Abbreviation', 1)

# %%
df_csv
# Out:
#                        Country Name  IPv6 Adoption Percentage  Latency  \
# 0                    American Samoa                      0.00      -10
# 1                           Andorra                      0.00        0
# 2                            Angola                      0.00        0
# 3                          Anguilla                      0.00        0
# 4                        Antarctica                      0.00        0
# 5                 Antigua & Barbuda                      0.00       10
# 6                         Argentina                      7.86        0
# 7                           Armenia                      1.63        0
# 8                             Aruba                      0.00        0
# 9                         Australia                     16.85        0
# 10                          Austria                     10.54        0
# 11                       Azerbaijan                      0.00        0
# ...

# %%
# Out:
#                     Country Name  IPv6 Adoption Percentage  Latency  Impact  \
# 0                 American Samoa                      0.00      -10   -0.04
# 111                      Jamaica                      0.00        0    0.01
# 117                     Kiribati                      0.00        0    0.00
# 237                       Tuvalu                      0.00        0    0.00
# 120                   Kyrgyzstan                      0.00        0    0.00
# 124                      Lesotho                      0.00        0    0.17
# 126                        Libya                      0.00        0   -0.01
# 248                      Vanuatu                      0.00       10    0.12
# 131                   Madagascar                      0.00        0    0.02
# 137             Marshall Islands                      0.00        0    0.00
# 139                   Mauritania                      0.00      -10    0.01
# ...

# %%
df_csv = df_csv.drop('Repeat', 1)

# %%
df_csv
# Out:
#                        Country Name  IPv6 Adoption Percentage  Latency  Impact
# 0                    American Samoa                      0.00      -10   -0.04
# 1                           Andorra                      0.00        0    0.01
# 2                            Angola                      0.00        0   -0.05
# 3                          Anguilla                      0.00        0   -0.05
# 4                        Antarctica                      0.00        0    0.00
# 5                 Antigua & Barbuda                      0.00       10   -0.06
# 6                         Argentina                      7.86        0    0.00
# 7                           Armenia                      1.63        0    0.00
# 8                             Aruba                      0.00        0    0.01
# 9                         Australia                     16.85        0    0.00
# 10                          Austria                     10.54        0   -0.01
# ...

# %%
#How is Adoption Percentage, latency, and impact defined

# %%
sort_by_adoption = df_csv.sort_values('IPv6 Adoption Percentage')

# %%
sort_by_adoption
# Out:
#                     Country Name  IPv6 Adoption Percentage  Latency  Impact
# 0                 American Samoa                      0.00      -10   -0.04
# 111                      Jamaica                      0.00        0    0.01
# 117                     Kiribati                      0.00        0    0.00
# 237                       Tuvalu                      0.00        0    0.00
# 120                   Kyrgyzstan                      0.00        0    0.00
# 124                      Lesotho                      0.00        0    0.17
# 126                        Libya                      0.00        0   -0.01
# 248                      Vanuatu                      0.00       10    0.12
# 131                   Madagascar                      0.00        0    0.02
# 137             Marshall Islands                      0.00        0    0.00
# 139                   Mauritania                      0.00      -10    0.01
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-e139c9bd5c3d> in <module>
#       1 df = pd.DataFrame({'IPv6 Adoption Percentage': IPv6_Adoption,
# ----> 2                   'Latency':Latency,
#       3                   'Impact': Impact}, index='Country_Name')
#
# NameError: name 'Latency' is not defined

# %%
IPv6_Adoption = df_csv['IPv6 Adoption Percentage']

# %%
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
# 5       0.00
# 6       7.86
# 7       1.63
# 8       0.00
# 9      16.85
# 10     10.54
# 11      0.00
# 12      0.00
# 13      0.00
# 14      0.04
# 15      0.00
# 16      0.04
# 17     52.83
# 18      3.34
# 19      0.01
# 20      0.00
# 21      4.54
# 22     13.48
# 23      4.75
# 24      0.00
# 25      0.00
# 26     27.66
# 27      0.00
# 28      0.88
# 29      0.00
#        ...
# 230     0.00
# 231     0.26
# 232    20.60
# 233     0.01
# 234     0.01
# 235     0.70
# 236     0.00
# 237     0.00
# 238     0.00
# 239     0.10
# 240     0.27
# 241     2.02
# 242    13.77
# 243    23.24
# 244    38.02
# 245     1.61
# 246    36.89
# 247     0.10
# 248     0.00
# 249     0.00
# 250     0.00
# 251    38.74
# 252     0.00
# 253     0.00
# 254     0.00
# 255     0.02
# 256     0.00
# 257     0.70
# 258     5.91
# 259    25.54
# Name: IPv6 Adoption Percentage, Length: 260, dtype: float64

# %%
Latency = df_csv['Latency']

# %%
Impact = df_csv['Impact']

# %%
Country_Name = df_csv['Country Name']

# %%
country_list
# Out:
# <bound method IndexOpsMixin.tolist of 0                      American Samoa
# 1                             Andorra
# 2                              Angola
# 3                            Anguilla
# 4                          Antarctica
# 5                   Antigua & Barbuda
# 6                           Argentina
# 7                             Armenia
# 8                               Aruba
# 9                           Australia
# 10                            Austria
# 11                         Azerbaijan
# 12                            Bahamas
# 13                            Bahrain
# 14                         Bangladesh
# 15                           Barbados
# 16                            Belarus
# 17                            Belgium
# 18                             Belize
# 19                              Benin
# 20                            Bermuda
# 21                             Bhutan
# 22                            Bolivia
# 23               Bosnia & Herzegovina
# ...

# %%
country_list = df_csv['Country Name'].tolist()

# %%
df_csv.columns
# Out:
# Index(['Country Name', 'IPv6 Adoption Percentage', 'Latency', 'Impact'], dtype='object')

# %%
df = pd.DataFrame({'IPv6 Adoption Percentage': df_csv['IPv6 Adoption Percentage'],
                  'Latency':df_csv["Latency"],
                  'Impact': df_csv["Impact"]}, index= country_list)

# %%
df = df_csv.set_index('Country Name')
df
# Out:
#                                 IPv6 Adoption Percentage  Latency  Impact
# Country Name
# American Samoa                                      0.00      -10   -0.04
# Andorra                                             0.00        0    0.01
# Angola                                              0.00        0   -0.05
# Anguilla                                            0.00        0   -0.05
# Antarctica                                          0.00        0    0.00
# Antigua & Barbuda                                   0.00       10   -0.06
# Argentina                                           7.86        0    0.00
# Armenia                                             1.63        0    0.00
# Aruba                                               0.00        0    0.01
# Australia                                          16.85        0    0.00
# Austria                                            10.54        0   -0.01
# ...

# %%
ax = df.plot.bar(rot = 0)

# %%
axes = df.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=2)

# %%
ipv6 = df['IPv6 Adoption Percentage'].plot.bar(rot = 0)

# %%
df['IPv6 Adoption Percentage'].plot.hist()

# %%
df['Latency'].plot.hist()

# %%
df['Impact'].plot.hist()

# %%
#latency: the delay before a transfer of data begins following an instruction for its transfer.
